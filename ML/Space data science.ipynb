# %%
import pandas as pd
import numpy as np
import sklearn as skl
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
#import tensorflow as tf

# %%
data = pd.read_csv("problem_dataset.csv")

# %%
data
# Out:
#           kepid  tce_plnt_num  tce_rogue_flag  tce_period  tce_period_err  \
# 0       4079482             3             NaN    0.726411    0.000000e+00
# 1       6716021             1             NaN  110.756000    1.148840e-04
# 2       6762992             2             NaN    0.562156    2.558700e-05
# 3      10120971             1             NaN  541.945000    1.432600e-02
# 4       8560285             1             NaN   85.340900    2.890610e-05
# ...         ...           ...             ...         ...             ...
# 14995   8874090             1             NaN   13.324000    5.339980e-05
# 14996   5122112             1             NaN    3.055170    2.570190e-07
# 14997   7031767             1             NaN    0.566754    1.116110e-05
# 14998   5392514             1             NaN    0.536850    1.257200e-05
# 14999   9785454             1             NaN  184.520000    5.486120e-05
#
#        tce_time0bk  tce_time0bk_err  tce_impact  tce_impact_err  tce_duration  \
# ...

# %%
data.columns
# Out:
# Index(['kepid', 'tce_plnt_num', 'tce_rogue_flag', 'tce_period',
#        'tce_period_err', 'tce_time0bk', 'tce_time0bk_err', 'tce_impact',
#        'tce_impact_err', 'tce_duration', 'tce_duration_err', 'tce_depth',
#        'tce_depth_err', 'tce_model_snr', 'tce_prad', 'tce_prad_err', 'tce_eqt',
#        'tce_eqt_err', 'tce_insol', 'tce_insol_err', 'tce_steff',
#        'tce_steff_err', 'tce_slogg', 'tce_slogg_err', 'tce_sradius',
#        'tce_sradius_err', 'av_training_set'],
#       dtype='object')

# %%
delete = ["kepid","tce_plnt_num","tce_rogue_flag","tce_insol","tce_insol_err"]
data_new = data.drop(delete,axis=1)

# %%
data_new
# Out:
#        tce_period  tce_period_err  tce_time0bk  tce_time0bk_err  tce_impact  \
# 0        0.726411    0.000000e+00      131.657         0.000000     0.10000
# 1      110.756000    1.148840e-04      144.800         0.000786     0.91320
# 2        0.562156    2.558700e-05      131.674         0.003974     0.20970
# 3      541.945000    1.432600e-02      442.273         0.016891     0.06049
# 4       85.340900    2.890610e-05      215.530         0.000302     0.78990
# ...           ...             ...          ...              ...         ...
# 14995   13.324000    5.339980e-05      135.243         0.003327     0.70070
# 14996    3.055170    2.570190e-07      134.437         0.000044     0.92250
# 14997    0.566754    1.116110e-05      131.870         0.003102     0.36440
# 14998    0.536850    1.257200e-05      131.803         0.003200     0.70780
# 14999  184.520000    5.486120e-05      237.699         0.000217     0.89120
#
# ...

# %%
Y = data_new.iloc[:,-1]
X = data_new.iloc[:,:-1]
# train,test = train_test_split

train_X, test_X, train_Y, test_Y = train_test_split(X,Y,test_size = 0.2)
print(train_X.shape)
# Out:
# (12000, 21)

# %%
model = RFC(n_estimators=10000)
model.fit(train_X,train_Y)

# %%
model.score(train_X,train_Y)
# Out:
# 1.0

# %%
pred_train = model.predict(train_X)
(np.where(pred_train== train_Y))
# Out:
# (array([    0,     1,     2, ..., 11997, 11998, 11999]),)

# %%
model.score(test_X,test_Y)
# Out:
# 0.6446666666666667

# %%
pred_test = model.predict(test_X)

len(np.where(pred_test == test_Y)[0])
# Out:
# 1934

# %%
nearest = KNeighborsClassifier(n_neighbors=100)
nearest.fit(train_X,train_Y)
# Out:
# KNeighborsClassifier(n_neighbors=100)

# %%
nearest.score(train_X,train_Y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# 0.1775

# %%
normal = StandardScaler()
train_X = normal.fit_transform(train_X)
test_X = normal.fit_transform(test_X)

# %%
logistic = LogisticRegression(max_iter= 1000000000,tol=1e-20)
logistic.fit(train_X,train_Y)
# Out:
# LogisticRegression(max_iter=1000000000, tol=1e-20)

# %%
logistic.score(train_X,train_Y)
# Out:
# 0.5976666666666667

# %%
logistic.score(test_X,test_Y)
# Out:
# 0.5933333333333334

# %%
neural = MLPClassifier(hidden_layer_sizes=(640,1280,2560,1280,640,64))
neural.fit(train_X,train_Y)

# %%
neural.score(train_X,train_Y)
# Out:
# 0.7994166666666667

# %%
neural.score(test_X,test_Y)
# Out:
# 0.5723333333333334
